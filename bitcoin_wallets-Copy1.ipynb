# %%
import numpy as np # library to handle data in a vectorized manner
import requests # library to handle requests
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# %%
pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
import lxml

# %%
res2019a=pd.read_csv('list address.csv')

# %%
res2019a.shape
# Out:
# (420, 1)

# %%
#res2019a['Address_new'] = res2019a['Address_new'].astype('|S') # which will by default set the length to the max len it encounters

# %%
#dfad = res2019a.filter(['Address_new'])

# %%
pd.set_option("display.max_rows", 500)

# %%
pd.get_option("display.max_rows")
# Out:
# 500

# %%
#res2019a

# %%
dflunghi=res2019a[res2019a['Address_new'].map(len) > 60]

# %%
dflunghi
# Out:
#                                            Address_new
# 2    bc1qgdjqv0av3q56jvd82tkdjpy7gdp9ut8tlqmgrpmv24...
# 46   bc1qww95hxxsm469pjt83qnxfqvfur38hdlpsfksrhtt2y...
# 85   bc1qzk2pyxtahg64cx6gyq02vrw65fdxtpr253r4ygww9n...
# 91   bc1qwfgdjyy95aay2686fn74h6a4nu9eev6np7q4fn204d...
# 100  bc1qfd9wg4eh4ey7ar9my04xk67mxf7rax8nkuwqjqwptt...
# 113  bc1qpwryujh5cdl0nqneu3sheehrah68ru533qz3slpv7j...
# 183  bc1qel7tps3wu6zqztaanczvt76hffwh7k06jd8r9xh2v3...
# 217  bc1qww95hxxsm469pjt83qnxfqvfur38hdlpsfksrhtt2y...
# 256  bc1qzk2pyxtahg64cx6gyq02vrw65fdxtpr253r4ygww9n...
# 262  bc1qwfgdjyy95aay2686fn74h6a4nu9eev6np7q4fn204d...
# 271  bc1qfd9wg4eh4ey7ar9my04xk67mxf7rax8nkuwqjqwptt...
# 284  bc1qpwryujh5cdl0nqneu3sheehrah68ru533qz3slpv7j...
# 354  bc1qel7tps3wu6zqztaanczvt76hffwh7k06jd8r9xh2v3...
# 378  bc1qr96m8kupk7sa2zztlxhlcwxu6uv665jdcx92ag5fpv...

# %%
#res2019a = dflunghi.drop

# %%
res2019a=res2019a[res2019a['Address_new'].map(len) < 60]

# %%
res2019a.shape
# Out:
# (406, 1)

# %%
df=res2019a

# %%
df
# Out:
#                                     Address_new
# 0            35hK24tcLEWcgNA4JxpvbkNkoAcDGqQPsP
# 1            34xp4vRoCGJym3xR7yCVPFHoCNxv4Twseo
# 3            1P5ZEDWTKTFGxQjZphgWPQUpe554WKDfHQ
# 4            38UmuUqPCrFmQo4khkomQwZ4VbY2nZMJ67
# 5            3Kzh9qAqVWQhEsfQz7zEQL1EuSx5tyNLNS
# 6            385cR5DM96n1HvBDMzLHPYcw89fZAXULJP
# 7            3D8qAoMkZ8F1b42btt2Mn5TyN7sWfa434A
# 8            1NDyJtNTjmwk5xPNhjgAMu4HDHigtobu1s
# 9            3LCGsSmfr24demGvriN4e3ft8wEcDuHFqh
# 10           3EiEN1JJCudBgAwL7c6ajqnPzx9LrK1VT6
# 11           36KAwNUR8VeLpUfGwdk7LEN6F4yvoRWMjn
# 12           3ETUmNhL2JuCFFVNSpk8Bqx2eorxyP9FVh
# 13           1AnwDVbwsLBVwRfqN2x9Eo4YEJSPXo2cwG
# 14           1MDq7zyLw6oKichbFiDDZ3aaK59byc6CT8
# 15           14eQD1QQb8QFVG8YFwGz7skyzsvBLWLwJS
# 16            1aXzEKiDJKzkPxTZy9zGc3y1nCDwDPub2
# 17           3DVJfEsDTPkGDvqPCLC41X85L1B1DQWDyh
# 18           3H5JTt42K7RmZtromfTSefcMEFMMe18pMD
# 19           19iqYbeATe4RxghQZJnYVFU4mjUUu76EA6
# ...

# %%
for index, row in res2019a.iterrows():
    print(row['Address_new'])
# Out:
# 35hK24tcLEWcgNA4JxpvbkNkoAcDGqQPsP
# 34xp4vRoCGJym3xR7yCVPFHoCNxv4Twseo
# 1P5ZEDWTKTFGxQjZphgWPQUpe554WKDfHQ
# 38UmuUqPCrFmQo4khkomQwZ4VbY2nZMJ67
# 3Kzh9qAqVWQhEsfQz7zEQL1EuSx5tyNLNS
# 385cR5DM96n1HvBDMzLHPYcw89fZAXULJP
# 3D8qAoMkZ8F1b42btt2Mn5TyN7sWfa434A
# 1NDyJtNTjmwk5xPNhjgAMu4HDHigtobu1s
# 3LCGsSmfr24demGvriN4e3ft8wEcDuHFqh
# 3EiEN1JJCudBgAwL7c6ajqnPzx9LrK1VT6
# 36KAwNUR8VeLpUfGwdk7LEN6F4yvoRWMjn
# 3ETUmNhL2JuCFFVNSpk8Bqx2eorxyP9FVh
# 1AnwDVbwsLBVwRfqN2x9Eo4YEJSPXo2cwG
# 1MDq7zyLw6oKichbFiDDZ3aaK59byc6CT8
# 14eQD1QQb8QFVG8YFwGz7skyzsvBLWLwJS
# 1aXzEKiDJKzkPxTZy9zGc3y1nCDwDPub2
# 3DVJfEsDTPkGDvqPCLC41X85L1B1DQWDyh
# 3H5JTt42K7RmZtromfTSefcMEFMMe18pMD
# 19iqYbeATe4RxghQZJnYVFU4mjUUu76EA6
# 35pgGeez3ou6ofrpjt8T7bvC9t6RrUK4p6
# 3BMEXqGpG4FxBA1KWhRFufXfSTRgzfDBhJ
# 3HroDXv8hmzKRtaSfBffRgedKpru8fgy6M
# 1LfV1tSt3KNyHpFJnAzrqsLFdeD2EvU1MK
# 1Kd6zLb9iAjcrgq8HzWnoWNVLYYWjp3swA
# 3FpYfDGJSdkMAvZvCrwPHDqdmGqUkTsJys
# 3BMEXxSMT2b2kvsnC4Q35d2kKJZ4u9bSLh
# 17CzhFvGwH6TT46JtzhnhMpTw4mHYpEGCR
# ...

# %%
import requests
import time
url1='https://bitinfocharts.com/bitcoin/address/'
columns = ['Block','Time','Amount','Balance', 'Balance, USD']
url2='-full'
a=[]
#res2019a=res2019a.reset_index(drop=True)

for index, row in df.iterrows():
    a=row['Address_new']
    url3=url1+str(a)+url2
    header = {"User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36","X-Requested-With": "XMLHttpRequest"
    }
    r = requests.get(url3, headers=header)
    dfs = pd.read_html(r.text)
    df=dfs[2]
    df=df.drop('Block',1)
    df["Time"] = pd.to_datetime(df["Time"])
    df['Amount'] = [x.split(' ')[0] for x in df['Amount']]
    df[['Amount']] = df[['Amount']].astype(str)
    df['Price']=df['Balance, USD'].str.split('$').str[-1].str.strip()
    cols = ['Amount','Price']
    df[cols] = df[cols].apply(lambda x: pd.to_numeric(x.astype(str).str.replace(',','')))
    df = df.loc[(df['Amount'] > 1) | (df['Amount']<0)]  
    filename = f'{a}.csv'
    df.to_csv(filename, encoding='utf-8',index=False, header=True)
    time.sleep(5)
else:
    print("Finally finished!")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-f920334fede4> in <module>
#      14     r = requests.get(url3, headers=header)
#      15     dfs = pd.read_html(r.text)
# ---> 16     df=dfs[2]
#      17     df=df.drop('Block',1)
#      18     df["Time"] = pd.to_datetime(df["Time"])
#
# IndexError: list index out of range

# %%
a

# %%
url3

# %%
#### Using .loc or df=df.reset_index(drop=True)

# %%
res2019a=res2019a.reset_index(drop=True)

# %%
res2019a
